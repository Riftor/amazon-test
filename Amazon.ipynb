# %%
import pandas as pd

df = pd.read_csv("don's-orders-amazon.csv")
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   02/14/06  103-9314023-6083001             Visa - 7590  Amazon.com
# 1   03/01/06  103-4950010-4676660             Visa - 7590  Amazon.com
# 2   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 3   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 4   12/19/07  104-4039289-6693826             Visa - 4680  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN        dredam@gmail.com      02/15/06
# 1                    NaN        dredam@gmail.com      03/03/06
# 2                    NaN        dredam@gmail.com      06/11/07
# 3                    NaN        dredam@gmail.com      06/12/07
# 4                    NaN        dredam@gmail.com      12/20/07
#
#   Shipping Address Name     Shipping Address Street 1  \
# 0              Don Edam  10025 Valley View Rd Ste 110
# ...

# %%
df.shape
# Out:
# (529, 23)

# %%
df = df.fillna(0)
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   02/14/06  103-9314023-6083001             Visa - 7590  Amazon.com
# 1   03/01/06  103-4950010-4676660             Visa - 7590  Amazon.com
# 2   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 3   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 4   12/19/07  104-4039289-6693826             Visa - 4680  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0        dredam@gmail.com      02/15/06
# 1                    0.0        dredam@gmail.com      03/03/06
# 2                    0.0        dredam@gmail.com      06/11/07
# 3                    0.0        dredam@gmail.com      06/12/07
# 4                    0.0        dredam@gmail.com      12/20/07
#
#   Shipping Address Name     Shipping Address Street 1  \
# 0              Don Edam  10025 Valley View Rd Ste 110
# ...

# %%
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   02/14/06  103-9314023-6083001             Visa - 7590  Amazon.com
# 1   03/01/06  103-4950010-4676660             Visa - 7590  Amazon.com
# 2   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 3   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 4   12/19/07  104-4039289-6693826             Visa - 4680  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0        dredam@gmail.com      02/15/06
# 1                    0.0        dredam@gmail.com      03/03/06
# 2                    0.0        dredam@gmail.com      06/11/07
# 3                    0.0        dredam@gmail.com      06/12/07
# 4                    0.0        dredam@gmail.com      12/20/07
#
#   Shipping Address Name     Shipping Address Street 1  \
# 0              Don Edam  10025 Valley View Rd Ste 110
# ...

# %%
df["Total Charged"].sum()
# Out:
# 28321.739999999998

# %%
df["Total Charged"].mean()
# Out:
# 53.63965909090911

# %%
df["Total Charged"].median()
# Out:
# 33.489999999999995

# %%
df["Total Charged"].max()
# Out:
# 489.0

# %%
df["Total Charged"].min()
# Out:
# 0.87

# %%
df["Tax Charged"] = df["Tax Charged"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-13-12937a1c27cb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$', '').astype(float)

# %%
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   02/14/06  103-9314023-6083001             Visa - 7590  Amazon.com
# 1   03/01/06  103-4950010-4676660             Visa - 7590  Amazon.com
# 2   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 3   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 4   12/19/07  104-4039289-6693826             Visa - 4680  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0        dredam@gmail.com      02/15/06
# 1                    0.0        dredam@gmail.com      03/03/06
# 2                    0.0        dredam@gmail.com      06/11/07
# 3                    0.0        dredam@gmail.com      06/12/07
# 4                    0.0        dredam@gmail.com      12/20/07
#
#   Shipping Address Name     Shipping Address Street 1  \
# 0              Don Edam  10025 Valley View Rd Ste 110
# ...

# %%
df["Total Promotions"] = df["Total Promotions"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-15-d0660ba68a2a>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Total Promotions"] = df["Total Promotions"].str.replace('$', '').astype(float)

# %%
df["Tax Before Promotions"] = df["Tax Before Promotions"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-16-c8fa7a298441>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Tax Before Promotions"] = df["Tax Before Promotions"].str.replace('$', '').astype(float)

# %%
df["Shipping Charge"] = df["Shipping Charge"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-17-0e554cef4efb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Shipping Charge"] = df["Shipping Charge"].str.replace('$', '').astype(float)

# %%
df["Subtotal"] = df["Subtotal"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-18-efac67b211f4>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Subtotal"] = df["Subtotal"].str.replace('$', '').astype(float)

# %%
pd.read_csv("don's-orders-amazon.csv")
# Out:
#     Order Date             Order ID                Payment Instrument Type  \
# 0     02/14/06  103-9314023-6083001                            Visa - 7590
# 1     03/01/06  103-4950010-4676660                            Visa - 7590
# 2     06/10/07  105-1581309-2793256                            Visa - 7590
# 3     06/10/07  105-1581309-2793256                            Visa - 7590
# 4     12/19/07  104-4039289-6693826                            Visa - 4680
# 5     11/04/08  002-3765329-3646624                            Visa - 4680
# 6     11/04/08  002-3086360-6817066                            Visa - 4680
# 7     12/16/08  105-7091396-9683443                            Visa - 4680
# 8     12/16/08  105-7091396-9683443                            Visa - 4680
# 9     02/09/09  104-0844864-1061060                American Express - 5357
# 10    02/13/09  104-1869149-9054639                            Visa - 4680
# ...

# %%
Amazon_history = pd.read_csv("don's-orders-amazon.csv")

# %%
Amazon_history
# Out:
#     Order Date             Order ID                Payment Instrument Type  \
# 0     02/14/06  103-9314023-6083001                            Visa - 7590
# 1     03/01/06  103-4950010-4676660                            Visa - 7590
# 2     06/10/07  105-1581309-2793256                            Visa - 7590
# 3     06/10/07  105-1581309-2793256                            Visa - 7590
# 4     12/19/07  104-4039289-6693826                            Visa - 4680
# 5     11/04/08  002-3765329-3646624                            Visa - 4680
# 6     11/04/08  002-3086360-6817066                            Visa - 4680
# 7     12/16/08  105-7091396-9683443                            Visa - 4680
# 8     12/16/08  105-7091396-9683443                            Visa - 4680
# 9     02/09/09  104-0844864-1061060                American Express - 5357
# 10    02/13/09  104-1869149-9054639                            Visa - 4680
# ...

# %%
df = pd.read_csv("don's-orders-amazon.csv")

# %%
df = df.fillna(0)

# %%
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   02/14/06  103-9314023-6083001             Visa - 7590  Amazon.com
# 1   03/01/06  103-4950010-4676660             Visa - 7590  Amazon.com
# 2   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 3   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 4   12/19/07  104-4039289-6693826             Visa - 4680  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0        dredam@gmail.com      02/15/06
# 1                    0.0        dredam@gmail.com      03/03/06
# 2                    0.0        dredam@gmail.com      06/11/07
# 3                    0.0        dredam@gmail.com      06/12/07
# 4                    0.0        dredam@gmail.com      12/20/07
#
#   Shipping Address Name     Shipping Address Street 1  \
# 0              Don Edam  10025 Valley View Rd Ste 110
# ...

# %%
df["Tax Charged"] = df["Tax Charged"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-29-12937a1c27cb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$', '').astype(float)

# %%
df["Subtotal"] = df["Subtotal"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-30-efac67b211f4>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Subtotal"] = df["Subtotal"].str.replace('$', '').astype(float)

# %%
df["Shipping Charge"] = df["Shipping Charge"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-31-0e554cef4efb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Shipping Charge"] = df["Shipping Charge"].str.replace('$', '').astype(float)

# %%
df["Tax Before Promotions"] = df["Tax Before Promotions"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-32-c8fa7a298441>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Tax Before Promotions"] = df["Tax Before Promotions"].str.replace('$', '').astype(float)

# %%
df["Total Promotions"] = df["Total Promotions"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-33-d0660ba68a2a>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Total Promotions"] = df["Total Promotions"].str.replace('$', '').astype(float)

# %%
df["Total Charged"] = df["Total Charged"].str.replace('$', '').astype(float)
# Out:
# <ipython-input-34-20e827fb8b8b>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Total Charged"] = df["Total Charged"].str.replace('$', '').astype(float)

# %%
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   02/14/06  103-9314023-6083001             Visa - 7590  Amazon.com
# 1   03/01/06  103-4950010-4676660             Visa - 7590  Amazon.com
# 2   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 3   06/10/07  105-1581309-2793256             Visa - 7590  Amazon.com
# 4   12/19/07  104-4039289-6693826             Visa - 4680  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0        dredam@gmail.com      02/15/06
# 1                    0.0        dredam@gmail.com      03/03/06
# 2                    0.0        dredam@gmail.com      06/11/07
# 3                    0.0        dredam@gmail.com      06/12/07
# 4                    0.0        dredam@gmail.com      12/20/07
#
#   Shipping Address Name     Shipping Address Street 1  \
# 0              Don Edam  10025 Valley View Rd Ste 110
# ...

# %%
Total_Spent_Ever
# Out:
# 28321.739999999998

# %%
Average_Spent_Ever = df["Total Charge"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Charge'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-485582834ec2> in <module>
# ...

# %%
Average_Spent_Ever = df["Total Charged"].mean()

# %%
Average_Spent_Ever
# Out:
# 53.63965909090911

# %%
Most_Expensive_Item = df["Total Charged"].max()

# %%
Most_Expensive_Item
# Out:
# 489.0

# %%
Least_Expensive_Item = df["Total Charged"].min()

# %%
Least_Expensive_Item
# Out:
# 0.87

# %%
Total_Number_Purchases = print("(First Number)"), df.shape
# Out:
# (First Number)

# %%
Total_Number_Purchases
# Out:
# (None, (529, 23))

# %%
Total_Number_Purchases = print(df.shape, "(First Number)")
# Out:
# (529, 23) First Number

# %%
Total_Number_Purchases = print(df.shape, "(First Number)")
# Out:
# (529, 23) (First Number)

# %%
Total_Number_Purchases

# %%
Total_Number_Purchases

# %%
Total_Number_Purchases = 529

# %%
Total_Number_Purchases
# Out:
# 529

# %%
Total_Shipping_Paid = df["Shipping Charge"].sum()

# %%
Total_Shipping_Paid
# Out:
# 311.1

# %%
Total_Money_Saved = df["Total Promotions"].sum()

# %%
Total_Money_Saved
# Out:
# 1039.8400000000001

# %%
helpme = Here are commands you can type:\n Amazon_history\n Total_Spent_Ever\n Average_Spent_Ever\n Most_Expensive_Item\n Least_Expensive_Item\n Total_Number_Purchases\n Total_Shipping_Paid\n Total_Money_Saved  ")
# Out:
# Here are commands you can type:
#  Amazon_history
#  Total_Spent_Ever
#  Average_Spent_Ever
#  Most_Expensive_Item
#  Least_Expensive_Item
#  Total_Number_Purchases
#  Total_Shipping_Paid
#  Total_Money_Saved

# %%
helpme

# %%
helpme = Here are commands you can type:\n Amazon_history\n Total_Spent_Ever\n Average_Spent_Ever\n Most_Expensive_Item\n Least_Expensive_Item\n Total_Number_Purchases\n Total_Shipping_Paid\n Total_Money_Saved
# Out:
#   File "<ipython-input-63-728db6e34bea>", line 1
#     helpme = Here are commands you can type:\n Amazon_history\n Total_Spent_Ever\n Average_Spent_Ever\n Most_Expensive_Item\n Least_Expensive_Item\n Total_Number_Purchases\n Total_Shipping_Paid\n Total_Money_Saved
#                   ^
# SyntaxError: invalid syntax

# %%
helpme = "Here are commands you can type:
Amazon_history"
Total_Spent_Ever"
Average_Spent_Ever"
Most_Expensive_Item"
Least_Expensive_Item"
Total_Number_Purchases"
Total_Shipping_Paid"
Total_Money_Saved"
# Out:
#   File "<ipython-input-66-5ad6706e5385>", line 1
#     helpme = "Here are commands you can type:
#                                              ^
# SyntaxError: EOL while scanning string literal

# %%
helpme
# Out:
# 'Here are commands you can type:\n Amazon_history\n Total_Spent_Ever\n Average_Spent_Ever\n Most_Expensive_Item\n Least_Expensive_Item\n Total_Number_Purchases\n Total_Shipping_Paid\n Total_Money_Saved  '

# %%
helpme = "Here are commands you can type:"
"Amazon_history"
"Total_Spent_Ever"
"Average_Spent_Ever"
"Most_Expensive_Item"
"Least_Expensive_Item"
"Total_Number_Purchases"
"Total_Shipping_Paid"
"Total_Money_Saved"
# Out:
#   File "<ipython-input-67-3e057c6f0c6b>", line 1
#     helpme = "Here are commands you can type:
#                                              ^
# SyntaxError: EOL while scanning string literal

# %%
helpme = "Here are commands you can type:"
# Out:
# 'Total_Money_Saved'

# %%
helpme
# Out:
# 'Here are commands you can type:'

# %%
helpme = "Here are commands you can type: Amazon_history,  Total_Spent_Ever,  Average_Spent_Ever,  Most_Expensive_Item,  Least_Expensive_Item,  Total_Number_Purchases,  Total_Shipping_Paid,  Total_Money_Saved"

# %%
helpme
# Out:
# 'Here are commands you can type: Amazon_history,  Total_Spent_Ever,  Average_Spent_Ever,  Most_Expensive_Item,  Least_Expensive_Item,  Total_Number_Purchases,  Total_Shipping_Paid,  Total_Money_Saved'

# %%
Amazon_history
# Out:
#     Order Date             Order ID                Payment Instrument Type  \
# 0     02/14/06  103-9314023-6083001                            Visa - 7590
# 1     03/01/06  103-4950010-4676660                            Visa - 7590
# 2     06/10/07  105-1581309-2793256                            Visa - 7590
# 3     06/10/07  105-1581309-2793256                            Visa - 7590
# 4     12/19/07  104-4039289-6693826                            Visa - 4680
# 5     11/04/08  002-3765329-3646624                            Visa - 4680
# 6     11/04/08  002-3086360-6817066                            Visa - 4680
# 7     12/16/08  105-7091396-9683443                            Visa - 4680
# 8     12/16/08  105-7091396-9683443                            Visa - 4680
# 9     02/09/09  104-0844864-1061060                American Express - 5357
# 10    02/13/09  104-1869149-9054639                            Visa - 4680
# ...
